# %%
# http://datacamp-community-prod.s3.amazonaws.com/dbed353d-2757-4617-8206-8767ab379ab3

import csv 
import pandas as pd
import lyricsgenius
import numpy as np
import matplotlib.pyplot as plt

# %%
songs = pd.read_csv('All_popsong_feature_data.csv')
songs.head()
# Out:
#    rank  num sections  num unique sections  intro or chorus beg  choruses  \
# 0     0             7                    4                    1         3
# 1     0            10                    5                    0         5
# 2     0            12                    6                    1         8
# 3     0            10                    5                    1         6
# 4     0             5                    5                    0         1
#
#    verses
# 0       2
# 1       3
# 2       2
# 3       2
# 4       1

# %%
def histogram_of_feature(feature_name):
    hist_list = []
    for row in range(len(songs[feature_name])):
        number = songs[feature_name][row]
        if songs['rank'][row] == 0:
            hist_list.append(number)
    plt.hist(hist_list)
    plt.title('histogram of the '+str(feature_name)+' of songs in the dataset')
    #plt.ylabel('number of songs in the dataset')
    plt.xlabel(str(feature_name)+' of a song')

    hist_list = []
    for row in range(len(songs[feature_name])):
        number = songs[feature_name][row]
        if songs['rank'][row] == 1:
            hist_list.append(number)
    plt.hist(hist_list)

# %%
histogram_of_feature('choruses')

# %%
histogram_of_feature('verses')

# %%
histogram_of_feature('num sections')

# %%
histogram_of_feature('num unique sections')

# %%
histogram_of_feature('intro or chorus beg')

# %%
histogram_of_feature('rank')
